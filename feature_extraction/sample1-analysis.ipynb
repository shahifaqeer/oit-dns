# %%
from __future__ import division
import numpy as np
import os, sys
import matplotlib
#matplotlib.use('Agg')
# %matplotlib nbagg
import matplotlib.pyplot as plt
import pandas as pd
from collections import defaultdict

# %%
def getCDF(data):
    xdata = np.sort(data)
    ydata = [i/len(xdata) for i in range(len(xdata))]
    return xdata, ydata

# %%
df = pd.read_csv("../data/dns_data_cs/dns_all_20170124_20170130_sample.csv", sep="\t", error_bad_lines=False,
                names=['time', 'srcip', 'dstip', 'dnsquery'], ).fillna('')

# %%
df.head()

# %% [markdown]
# ## STATS

# %%
print "Total time of dns record [1.7GB]:", (df.iloc[-1]['time'] - df.iloc[0]['time']), "s"
print "Total number of queries: ", len(df)
print "Queries without source IP (are probably IPv6 so IP was not extracted): ", len(df[df['srcip']==''])

print "Unique source IPs (devices or homes):", len(df['srcip'].unique())
print "Unique destination IPs (DNS servers):", len(df['dstip'].unique())

print "Unique queries:", len(df['dnsquery'].unique())
# Out:
# Total time of dns record [1.7GB]: 50945.441681 s
# Total number of queries:  27537421
# Queries without source IP (are probably IPv6 so IP was not extracted):  148
# Unique source IPs (devices or homes): 17743
# Unique destination IPs (DNS servers): 1792
# Unique queries: 666723

# %% [markdown]
# ## KNOWN IOT DEVICES AND SPECIFIC DOMAINS

# %%
DNS_moderate_lookups = {
    'nest_therm': '.nest.com',
    'nest_cam': '.dropcam.com',
    'smartthings': '.smartthings.com',
    'pixstar': '.pix-star.com',
    'echo': 'device-metrics-us.amazon.com',
    'sharx': 'sharxsecurity.com',
    'august': '.august.com',
    'hue': '.meethue.com',
    #'apple': 'time-ios.apple.com',
    'apple': 'gs-loc.ls-apple.com',
    'ps': '.playstation.net',
    'xbox': 'xboxlive.com',
    'nintendo': 'nintendo.net',
}

# %%
iot_list = defaultdict(int)
for domain in DNS_moderate_lookups.values():
    if len(iot_list) == 0:
        iot_list = df['dnsquery'].str.contains(domain)
    else:
        iot_list = iot_list | df['dnsquery'].str.contains(domain)

# %%
df_iot = df[iot_list].copy()

# %%
len(df_iot)
# Out:
# 28605

# %% [markdown]
# ### Add corresponding device identified

# %%
inverse_DNS_lookups = {v: k for k, v in DNS_moderate_lookups.items()}
df_iot['device'] = ''

for domain in DNS_moderate_lookups.values():
    df_iot.loc[ df_iot['dnsquery'].str.contains(domain), 'device'] = inverse_DNS_lookups[domain]

# %%
df_iot.head()
# Out:
#           time         srcip     dstip                              dnsquery  \
# 277   0.326137    10.8.252.6  10.8.0.5          device-metrics-us.amazon.com
# 978    1.37333  10.8.117.252  10.8.0.6  us-prof.np.community.playstation.net
# 3319    4.8464   10.8.75.213  10.8.0.5          device-metrics-us.amazon.com
# 3491   5.10355   10.8.28.249  10.8.0.5                xsts.auth.xboxlive.com
# 3503   5.12828   10.8.28.249  10.8.0.6                xsts.auth.xboxlive.com
#
#      device
# 277    echo
# 978      ps
# 3319   echo
# 3491   xbox
# 3503   xbox

# %% [markdown]
# ### Device vs unique source IPs

# %%
df_iot_count = df_iot.groupby(['srcip', 'device'])['dnsquery'].count().reset_index()
df_iot_count.head()
# Out:
#         srcip device  dnsquery
# 0  10.8.0.179  apple         1
# 1  10.8.0.184  apple         2
# 2   10.8.0.22  apple         1
# 3  10.8.0.238   xbox         1
# 4   10.8.0.57  apple         3

# %%
gp = df_iot_count.groupby('device')

df_iot_dev_stats = pd.DataFrame( { 'count_srcip': gp['srcip'].count(),
                                  'mean_dnsquery_count': gp['dnsquery'].apply(lambda x: x.mean()),
                                  'std_dnsquery_count': gp['dnsquery'].apply(lambda x: x.std()) })

df_iot_dev_stats
# Out:
#              count_srcip  mean_dnsquery_count  std_dnsquery_count
# device
# apple               2231             4.076647            7.413595
# august                 3             2.333333            2.309401
# echo                 531            15.802260           34.900566
# hue                    7             2.714286            3.302236
# nest_cam              14             4.357143            3.855209
# nest_therm            32            10.843750           19.597744
# nintendo              39            23.461538           27.091314
# ps                    62            69.709677           98.517933
# smartthings            5             4.400000            2.701851
# xbox                 732             7.412568           18.132111

# %% [markdown]
# # IDENTIFY IOT DEVICES

# %% [markdown]
# ## NUM UNIQUE QUERIES PER DEVICE

# %%
gp1 = df.groupby(['srcip', 'dnsquery'])

# %%
df1 = gp1['time'].count().reset_index()

df1.head(20)
# Out:
#             srcip                                           dnsquery  time
# 0                                                                      148
# 1   10.24.117.145       _ldap._tcp.dc._msdcs.WORKGROUP.princeton.edu     1
# 2   10.24.117.145                 _ldap._tcp.dc._msdcs.princeton.edu     2
# 3   10.24.117.145                                     ajax.cdnjs.com     2
# 4   10.24.117.145                                http-test1.hola.org     2
# 5   10.24.117.145                               isatap.princeton.edu     4
# 6   10.24.117.145                            win8.ipv6.microsoft.com     2
# 7   10.24.117.145                                 wpad.princeton.edu     1
# 8   10.24.117.145                                     www.google.com     2
# 9   10.24.125.176                                                        6
# 10  10.24.125.176                           <Unknown extended label>     4
# 11  10.24.125.176  <Unknown extended label>,<Unknown extended label>     4
# 12  10.24.125.176  <Unknown extended label>,<Unknown extended lab...     2
# 13   10.24.175.34                           win10.ipv6.microsoft.com     2
# 14  10.24.193.171                               ios.nccp.netflix.com    34
# 15  10.24.231.132                           win10.ipv6.microsoft.com     7
# 16  10.25.115.108                                    ssl.gstatic.com     1
# 17  10.25.128.192             lb._dns-sd._udp.0.0.24.10.in-addr.arpa     1
# 18  10.25.128.192                                     www.google.com     1
# 19  10.25.181.202                               ios.nccp.netflix.com    32

# %%
len(df1)
# Out:
# 5062521

# %%
# filter away empty/unknown queries or those not containing a period
#df2 = df1[~( (df1['dnsquery']=='') | (df1['dnsquery'].str.contains("<Unknown extended label>")) )]
df2 = df1[ (df1['dnsquery'].str.contains(".")) & (~df1['dnsquery'].str.contains("<"))]

# %%
len(df2)
# Out:
# 5061798

# %%
# group query by sourceip and count num of individual queries per ip

gp2 = df2.groupby('srcip')
df3 = gp2['dnsquery'].count()

# %%
print "Number of source IPs =", len(df3)
# Out:
# Number of source IPs = 17633

# %%
len(df3)
# Out:
# 17633

# %%
df4 = df3[df3<=200]
len( df4 )
# Out:
# 9460

# %%
x,y = getCDF(df3.values)

fig1, ax1 = plt.subplots()
ax1.plot(x,y)
ax1.set_xscale("log", nonposx='clip')
ax1.grid(1)
ax1.set_xlabel('log number of unique queries')
ax1.set_ylabel('CDF fraction of IPs (total 17633)')
fig1.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
x,y = getCDF(df4.values)

fig1, ax1 = plt.subplots()
ax1.plot(x,y)
#ax1.set_xscale("log", nonposx='clip')
ax1.grid(1)
ax1.set_xlabel('log number of unique queries')
ax1.set_ylabel('CDF fraction of IPs <=200 queries')
fig1.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
x,y = getCDF(df3[df3<=1000].values)

fig1, ax1 = plt.subplots()
ax1.plot(x,y)
#ax1.set_xscale("log", nonposx='clip')
ax1.grid(1)
ax1.set_xlabel('log number of unique queries')
ax1.set_ylabel('CDF fraction of IPs <=1000 queries')
fig1.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
df3.sort()
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort is deprecated, use sort_values(inplace=True) for for INPLACE sorting
#   if __name__ == '__main__':

# %%
df_30 = df3[df3<=30]
print len(df_30)
print len(df3)
df_30
# Out:
# 3075
# 17633
# srcip
# 94.102.49.193       1
# 128.112.224.251     1
# 128.112.224.244     1
# 128.112.224.234     1
# 128.112.224.201     1
# 128.112.224.182     1
# 128.112.224.131     1
# 128.112.222.96      1
# 128.112.222.94      1
# 128.112.222.93      1
# 128.112.222.90      1
# 128.112.222.89      1
# 128.112.222.87      1
# 128.112.222.110     1
# 128.112.221.202     1
# 128.112.221.201     1
# 128.112.221.156     1
# 128.112.220.206     1
# 128.112.220.198     1
# 128.112.22.189      1
# 128.112.219.95      1
# 128.112.218.45      1
# 128.112.218.39      1
# 128.112.218.28      1
# 128.112.217.219     1
# 128.112.217.207     1
# 128.112.212.99      1
# 128.112.212.98      1
# 128.112.212.97      1
# 128.112.212.96      1
#                    ..
# 10.8.8.10          30
# 10.9.64.217        30
# 10.8.218.243       30
# 10.9.68.91         30
# 10.6.49.97         30
# 10.6.49.41         30
# 10.9.151.163       30
# 10.9.155.58        30
# 10.6.49.42         30
# 10.9.96.221        30
# 10.9.22.184        30
# 10.8.84.27         30
# 10.9.27.167        30
# 10.6.52.195        30
# 10.9.110.223       30
# 10.8.93.59         30
# 10.9.210.35        30
# 10.8.243.30        30
# 10.9.211.158       30
# 10.9.171.59        30
# 10.9.60.136        30
# 10.6.52.143        30
# 10.8.134.110       30
# 10.8.204.245       30
# 10.9.211.18        30
# 10.9.83.140        30
# 10.9.245.211       30
# 10.8.148.147       30
# 10.9.15.117        30
# 10.8.156.68        30
# Name: dnsquery, dtype: int64

# %%
df2.loc[gp2.indices['128.112.212.96']]
# Out:
#                    srcip              dnsquery  time
# 4838733  128.112.134.236  ims314.Princeton.EDU     2

# %%
#df2.loc[gp2.indices['10.9.211.18']]

# %% [markdown]
# ### Check IPs against df_iot

# %%
df_known_iot = df3.loc[df_iot_count.srcip].reset_index()
df_known_iot
# Out:
#                 srcip  dnsquery
# 0          10.8.0.179      1326
# 1          10.8.0.184       318
# 2           10.8.0.22        59
# 3          10.8.0.238       147
# 4           10.8.0.57       151
# 5           10.8.0.85       448
# 6           10.8.1.10       526
# 7          10.8.1.115       158
# 8          10.8.1.135       625
# 9          10.8.1.157       348
# 10         10.8.1.166       748
# 11         10.8.1.196       102
# 12         10.8.1.211      1127
# 13         10.8.1.220       108
# 14         10.8.1.236       237
# 15         10.8.1.238        61
# 16          10.8.1.61       816
# 17          10.8.1.67       394
# 18        10.8.10.112       822
# 19        10.8.10.115       484
# 20        10.8.10.163       130
# 21        10.8.10.170        90
# 22         10.8.10.20        62
# 23        10.8.10.208        93
# 24         10.8.10.48       323
# 25         10.8.10.53       422
# 26         10.8.10.56       757
# 27         10.8.10.69        21
# 28       10.8.100.130        14
# 29       10.8.100.169       383
# ...               ...       ...
# 3626      10.9.96.221        30
# 3627      10.9.96.241       418
# 3628       10.9.96.37        41
# 3629      10.9.97.116       119
# 3630      10.9.97.117       302
# 3631       10.9.97.14       770
# 3632      10.9.97.193       128
# 3633      10.9.97.234       585
# 3634      10.9.97.252      1404
# 3635      10.9.97.253       145
# 3636       10.9.97.93       869
# 3637      10.9.98.121       568
# 3638      10.9.98.143       205
# 3639      10.9.98.230       209
# 3640      10.9.98.233        37
# 3641      10.9.98.249       254
# 3642       10.9.98.36       539
# 3643       10.9.98.81       823
# 3644       10.9.98.98       647
# 3645       10.9.99.11        59
# 3646       10.9.99.19        82
# 3647      10.9.99.223       196
# 3648      10.9.99.227       370
# 3649      10.9.99.244       597
# 3650      10.9.99.255        64
# 3651        10.9.99.5       636
# 3652  140.180.220.102     74892
# 3653  140.180.220.103     75434
# 3654  140.180.223.155     36351
# 3655  140.180.223.156     23689
#
# [3656 rows x 2 columns]

# %%
df_iot_count.merge(df_known_iot, on='srcip')
# Out:
#                 srcip      device  dnsquery_x  dnsquery_y
# 0          10.8.0.179       apple           1        1326
# 1          10.8.0.184       apple           2         318
# 2           10.8.0.22       apple           1          59
# 3          10.8.0.238        xbox           1         147
# 4           10.8.0.57       apple           3         151
# 5           10.8.0.85       apple          10         448
# 6           10.8.1.10       apple           3         526
# 7          10.8.1.115        echo           5         158
# 8          10.8.1.135        echo           1         625
# 9          10.8.1.157       apple           8         348
# 10         10.8.1.166       apple           4         748
# 11         10.8.1.196       apple           6         102
# 12         10.8.1.211       apple           4        1127
# 13         10.8.1.220       apple           3         108
# 14         10.8.1.236       apple          14         237
# 15         10.8.1.238        echo           2          61
# 16          10.8.1.61        xbox           1         816
# 17          10.8.1.67       apple           2         394
# 18        10.8.10.112       apple           6         822
# 19        10.8.10.115        xbox           9         484
# 20        10.8.10.163        echo         346         130
# 21        10.8.10.170       apple           1          90
# 22         10.8.10.20        xbox           2          62
# 23        10.8.10.208        echo           2          93
# 24         10.8.10.48        echo           3         323
# 25         10.8.10.53       apple           3         422
# 26         10.8.10.56       apple           1         757
# 27         10.8.10.69          ps          11          21
# 28       10.8.100.130       apple           1          14
# 29       10.8.100.169        xbox          36         383
# ...               ...         ...         ...         ...
# 3760      10.9.96.221       apple           2          30
# 3761      10.9.96.241       apple           5         418
# 3762       10.9.96.37        echo         194          41
# 3763      10.9.97.116        echo           1         119
# 3764      10.9.97.117       apple           8         302
# 3765       10.9.97.14       apple           1         770
# 3766      10.9.97.193        xbox           2         128
# 3767      10.9.97.234        xbox           3         585
# 3768      10.9.97.252       apple          11        1404
# 3769      10.9.97.253       apple           1         145
# 3770       10.9.97.93       apple           1         869
# 3771      10.9.98.121       apple           2         568
# 3772      10.9.98.143        xbox           1         205
# 3773      10.9.98.230       apple           1         209
# 3774      10.9.98.233        xbox           2          37
# 3775      10.9.98.249       apple           2         254
# 3776       10.9.98.36       apple           1         539
# 3777       10.9.98.81        xbox           3         823
# 3778       10.9.98.98        xbox           1         647
# 3779       10.9.99.11        echo          85          59
# 3780       10.9.99.19        xbox         126          82
# 3781      10.9.99.223       apple           2         196
# 3782      10.9.99.227        xbox          19         370
# 3783      10.9.99.244       apple          23         597
# 3784      10.9.99.255        echo           3          64
# 3785        10.9.99.5       apple           3         636
# 3786  140.180.220.102  nest_therm          47       74892
# 3787  140.180.220.103  nest_therm          47       75434
# 3788  140.180.223.155  nest_therm          94       36351
# 3789  140.180.223.156  nest_therm          28       23689
#
# [3790 rows x 4 columns]

# %%
#df_temp = df[df['dnsquery'].str.contains('nest.com')]

# %%
#print( df_temp.to_string() )

# %%
#len(df_temp['srcip'].unique())

# %%
#df_temp2 = df[df['srcip']=='140.180.220.102']

# %%
#print( df_temp2.to_string() )

# %%
#df_temp2[df_temp2['dnsquery'].str.contains('tumblr')]
